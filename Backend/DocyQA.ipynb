# %% [markdown]
# #**DocyQA**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
import os 
os.chdir('gdrive/My Drive/Colab Notebooks')

# %%
# !pip install pdfplumber
# !pip install nltk
# !pip install -U gensim
# !pip install flask-ngrok
# !pip install werkzeug
# !pip install numpy
# Out:
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.7/dist-packages (0.5.28)
# Requirement already satisfied: pdfminer.six==20200517 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (20200517)
# Requirement already satisfied: Wand in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (0.6.7)
# Requirement already satisfied: Pillow>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (7.1.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20200517->pdfplumber) (3.0.4)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20200517->pdfplumber) (3.4.3)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20200517->pdfplumber) (2.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.7/dist-packages (0.0.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.11.1)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)

# %%
def pdf_extract(file_name):
  import pdfplumber
  directory = "docs"
  pdf_txt = ""
  for file in os.listdir(directory):
      filename = os.fsdecode(file)
      if(filename == file_name):
          pdf_txt = '' # new line
          with pdfplumber.open(directory + '/' + filename) as pdf:
              for pdf_page in pdf.pages:
                single_page_text = pdf_page.extract_text()
                pdf_txt = pdf_txt + single_page_text
  return pdf_txt

# %% [markdown]
# ##**Naive Approch**

# %%
import re
import gensim
from gensim.parsing.preprocessing import remove_stopwords

def clean_sentence(sentence, stopwords=False):
  sentence = sentence.lower().strip()
  sentence = re.sub(r'[^a-z0-9\s]', '', sentence)
  if stopwords:
    sentence = remove_stopwords(sentence)
  return sentence

def get_cleaned_sentences(tokens, stopwords=False):
  cleaned_sentences = []
  for row in tokens:
    cleaned = clean_sentence(row, stopwords)
    cleaned_sentences.append(cleaned)
  return cleaned_sentences

# %%
def retrieveAndPrintFAQAnswer(question_embedding, sentence_embeddings, sentences):
  import sklearn
  from sklearn.metrics.pairwise import cosine_similarity
  max_sim = -1
  index_sim = -1
  for index, embedding in enumerate(sentence_embeddings):
    sim = cosine_similarity(embedding, question_embedding)[0][0]
    if sim > max_sim:
      max_sim = sim
      index_sim = index
  
  return index_sim

# %%
def naive_drive(file_name, question):
  pdf_txt = pdf_extract(file_name)
  import nltk
  import numpy
  import pprint
  nltk.download('punkt')
  tokens = nltk.sent_tokenize(pdf_txt)
  cleaned_sentences = get_cleaned_sentences(tokens, stopwords=True)
  cleaned_sentences_with_stopwords = get_cleaned_sentences(tokens, stopwords=False)
  sentences = cleaned_sentences_with_stopwords
  sentence_words = [[word for word in document.split()]
                    for document in sentences]

  from gensim import corpora
  dictionary = corpora.Dictionary(sentence_words)
  bow_corpus = [dictionary.doc2bow(text) for text in sentence_words]

  question = clean_sentence(question, stopwords=False)
  question_embedding = dictionary.doc2bow(question.split())

  index = retrieveAndPrintFAQAnswer(question_embedding, bow_corpus, sentences)
  #return len(sentences)
  return sentences[index]

# %% [markdown]
# ##**Word2Vec Approach**

# %%
from gensim.models import Word2Vec
import gensim.downloader as api

v2w_model = None
try:
  v2w_model = gensim.models.Keyedvectors.load('./w2vecmodel.mod')
  print("w2v Model Successfully loaded")
except:
  v2w_model = api.load('word2vec-google-news-300')
  v2w_model.save("./w2vecmodel.mod")
  print("w2v Model Saved")

w2vec_embedding_size = len(v2w_model['pc'])
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# w2v Model Saved

# %%
def getWordVec(word, model):
  import numpy
  samp = model['pc']
  vec = [0]*len(samp)
  try:
    vec = model[word]
  except:
    vec = [0]*len(samp)
  return (vec)


def getPhraseEmbedding(phrase, embeddingmodel):
  import numpy
  samp = getWordVec('computer', embeddingmodel)
  vec = numpy.array([0]*len(samp))
  den = 0;
  for word in phrase.split():
    den = den+1
    vec = vec+numpy.array(getWordVec(word, embeddingmodel))
  return vec.reshape(1, -1)

# %%
def word2vec_drive(file_name, question):
  pdf_txt = pdf_extract(file_name)

  import nltk
  import numpy
  import pprint
  
  nltk.download('punkt')
  tokens = nltk.sent_tokenize(pdf_txt)
  cleaned_sentences = get_cleaned_sentences(tokens, stopwords=True)
  cleaned_sentences_with_stopwords = get_cleaned_sentences(tokens, stopwords=False)
  sentences = cleaned_sentences_with_stopwords
  sentence_words = [[word for word in document.split()]
                    for document in sentences]

  sent_embeddings = []
  for sent in sentences:
    sent_embeddings.append(getPhraseEmbedding(sent, v2w_model))

  question_embedding = getPhraseEmbedding(question, v2w_model)
  index = retrieveAndPrintFAQAnswer(question_embedding, sent_embeddings, cleaned_sentences_with_stopwords)
  return cleaned_sentences_with_stopwords[index]

# %% [markdown]
# ##**Glove Approach**

# %%
from gensim.models import Word2Vec
import gensim.downloader as api

glove_model = None
try:
  glove_model = gensim.models.Keyedvectors.load('./glovemodel.mod')
  print("Glove Model Successfully loaded")
except:
  glove_model = api.load('glove-twitter-25')
  glove_model.save("./glovemodel.mod")
  print("Glove Model Saved")

glove_embedding_size = len(glove_model['pc'])
# Out:
# Glove Model Saved

# %%
def glove_drive(file_name, question):
  pdf_txt = pdf_extract(file_name)

  import nltk
  import numpy
  import pprint

  nltk.download('punkt')
  tokens = nltk.sent_tokenize(pdf_txt)
  cleaned_sentences = get_cleaned_sentences(tokens, stopwords=True)
  cleaned_sentences_with_stopwords = get_cleaned_sentences(tokens, stopwords=False)
  sentences = cleaned_sentences_with_stopwords
  sentence_words = [[word for word in document.split()]
                    for document in sentences]

  sent_embeddings = []
  for sent in cleaned_sentences:
    sent_embeddings.append(getPhraseEmbedding(sent, glove_model))

  question_embedding = getPhraseEmbedding(question, glove_model)
  index = retrieveAndPrintFAQAnswer(question_embedding, sent_embeddings, cleaned_sentences_with_stopwords)
  return cleaned_sentences_with_stopwords[index]

# %%
# answer = glove_drive("1637834603676.pdf", "What was the highest fdi inflow in 2019?");
# print(answer)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# as a result of the measures taken to improve the countrys investment climate india
# jumped to 63rd place in world banks ease of doing business ranking as per world banks doing
# business report dbr 2020

# %% [markdown]
# #**Simple Transformer**

# %%
# !pip install simpletransformers
# Out:
# Requirement already satisfied: simpletransformers in /usr/local/lib/python3.7/dist-packages (0.63.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.62.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.0.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.1.96)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.4.1)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.15.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.7.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.1.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2019.12.20)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.10.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.23.0)
# Requirement already satisfied: wandb>=0.10.32 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.12.7)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.2.0)
# Requirement already satisfied: transformers>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.12.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (0.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (4.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (3.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (0.0.46)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers>=4.6.0->simpletransformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=4.6.0->simpletransformers) (3.0.6)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (0.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (5.4.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.8.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.5.0)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.5.4)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.1.24)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.15.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.0.8)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (5.1.0)
# Requirement already satisfied: yaspin>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.1.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (7.1.2)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.17.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2021.10.8)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb>=0.10.32->simpletransformers) (1.1.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (2.0.2)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (2021.11.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (3.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.3.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.70.12.2)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (3.0.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (4.0.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (2.0.7)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (21.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (5.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.6.0->simpletransformers) (3.6.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2018.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.6.0->simpletransformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->simpletransformers) (3.0.0)
# Requirement already satisfied: base58 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (2.1.1)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.9)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.4)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (2.1.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (7.1.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: blinker in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.4)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.8.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.7.1)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.1.0)
# Requirement already satisfied: validators in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.18.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.5.1)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.11.2)
# Requirement already satisfied: ipykernel>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (6.5.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (7.29.0)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.0)
# Requirement already satisfied: argcomplete>=1.12.3 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.12.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.1.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (57.4.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.0.22)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.8.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.9.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (22.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.12.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (3.3.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.42.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.37.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.35.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (3.1.1)

# %%
import json


with open('data/SQuAD_1.1/train-v1.1.json', 'r') as f:
    train_data = json.load(f)

train_data = [item for topic in train_data['data'] for item in topic['paragraphs'] ]

# %%
with open('data/SQuAD_1.1/dev-v1.1.json', 'r') as f:
    test_data = json.load(f)

test_data = [item for topic in test_data['data'] for item in topic['paragraphs'] ]

# %%
train_data[0]
# Out:
# {'context': 'Architecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.',
#  'qas': [{'answers': [{'answer_start': 515,
#      'text': 'Saint Bernadette Soubirous'}],
#    'question': 'To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?',
#    'id': '5733be284776f41900661182'},
#   {'answers': [{'answer_start': 188, 'text': 'a copper statue of Christ'}],
#    'question': 'What is in front of the Notre Dame Main Building?',
#    'id': '5733be284776f4190066117f'},
#   {'answers': [{'answer_start': 279, 'text': 'the Main Building'}],
#    'question': 'The Basilica of the Sacred heart at Notre Dame is beside to which structure?',
#    'id': '5733be284776f41900661180'},
#   {'answers': [{'answer_start': 381,
#      'text': 'a Marian place of prayer and reflection'}],
#    'question': 'What is the Grotto at Notre Dame?',
#    'id': '5733be284776f41900661181'},
#   {'answers': [{'answer_start': 92,
#      'text': 'a golden statue of the Virgin Mary'}],
#    'question': 'What sits on top of the Main Building at Notre Dame?',
#    'id': '5733be284776f4190066117e'}]}

# %%
test_data[0]
# Out:
# {'context': 'Super Bowl 50 was an American football game to determine the champion of the National Football League (NFL) for the 2015 season. The American Football Conference (AFC) champion Denver Broncos defeated the National Football Conference (NFC) champion Carolina Panthers 24–10 to earn their third Super Bowl title. The game was played on February 7, 2016, at Levi\'s Stadium in the San Francisco Bay Area at Santa Clara, California. As this was the 50th Super Bowl, the league emphasized the "golden anniversary" with various gold-themed initiatives, as well as temporarily suspending the tradition of naming each Super Bowl game with Roman numerals (under which the game would have been known as "Super Bowl L"), so that the logo could prominently feature the Arabic numerals 50.',
#  'qas': [{'answers': [{'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'}],
#    'question': 'Which NFL team represented the AFC at Super Bowl 50?',
#    'id': '56be4db0acb8001400a502ec'},
#   {'answers': [{'answer_start': 249, 'text': 'Carolina Panthers'},
#     {'answer_start': 249, 'text': 'Carolina Panthers'},
#     {'answer_start': 249, 'text': 'Carolina Panthers'}],
#    'question': 'Which NFL team represented the NFC at Super Bowl 50?',
#    'id': '56be4db0acb8001400a502ed'},
#   {'answers': [{'answer_start': 403, 'text': 'Santa Clara, California'},
#     {'answer_start': 355, 'text': "Levi's Stadium"},
#     {'answer_start': 355,
#      'text': "Levi's Stadium in the San Francisco Bay Area at Santa Clara, California."}],
#    'question': 'Where did Super Bowl 50 take place?',
#    'id': '56be4db0acb8001400a502ee'},
#   {'answers': [{'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'}],
#    'question': 'Which NFL team won Super Bowl 50?',
#    'id': '56be4db0acb8001400a502ef'},
#   {'answers': [{'answer_start': 488, 'text': 'gold'},
#     {'answer_start': 488, 'text': 'gold'},
#     {'answer_start': 521, 'text': 'gold'}],
#    'question': 'What color was used to emphasize the 50th anniversary of the Super Bowl?',
#    'id': '56be4db0acb8001400a502f0'},
#   {'answers': [{'answer_start': 487, 'text': '"golden anniversary"'},
#     {'answer_start': 521, 'text': 'gold-themed'},
#     {'answer_start': 487, 'text': '"golden anniversary'}],
#    'question': 'What was the theme of Super Bowl 50?',
#    'id': '56be8e613aeaaa14008c90d1'},
#   {'answers': [{'answer_start': 334, 'text': 'February 7, 2016'},
#     {'answer_start': 334, 'text': 'February 7'},
#     {'answer_start': 334, 'text': 'February 7, 2016'}],
#    'question': 'What day was the game played on?',
#    'id': '56be8e613aeaaa14008c90d2'},
#   {'answers': [{'answer_start': 133, 'text': 'American Football Conference'},
#     {'answer_start': 133, 'text': 'American Football Conference'},
#     {'answer_start': 133, 'text': 'American Football Conference'}],
#    'question': 'What is the AFC short for?',
#    'id': '56be8e613aeaaa14008c90d3'},
#   {'answers': [{'answer_start': 487, 'text': '"golden anniversary"'},
#     {'answer_start': 521, 'text': 'gold-themed'},
#     {'answer_start': 521, 'text': 'gold'}],
#    'question': 'What was the theme of Super Bowl 50?',
#    'id': '56bea9923aeaaa14008c91b9'},
#   {'answers': [{'answer_start': 133, 'text': 'American Football Conference'},
#     {'answer_start': 133, 'text': 'American Football Conference'},
#     {'answer_start': 133, 'text': 'American Football Conference'}],
#    'question': 'What does AFC stand for?',
#    'id': '56bea9923aeaaa14008c91ba'},
#   {'answers': [{'answer_start': 334, 'text': 'February 7, 2016'},
#     {'answer_start': 334, 'text': 'February 7'},
#     {'answer_start': 334, 'text': 'February 7, 2016'}],
#    'question': 'What day was the Super Bowl played on?',
#    'id': '56bea9923aeaaa14008c91bb'},
#   {'answers': [{'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'}],
#    'question': 'Who won Super Bowl 50?',
#    'id': '56beace93aeaaa14008c91df'},
#   {'answers': [{'answer_start': 355, 'text': "Levi's Stadium"},
#     {'answer_start': 355, 'text': "Levi's Stadium"},
#     {'answer_start': 355,
#      'text': "Levi's Stadium in the San Francisco Bay Area at Santa Clara"}],
#    'question': 'What venue did Super Bowl 50 take place in?',
#    'id': '56beace93aeaaa14008c91e0'},
#   {'answers': [{'answer_start': 403, 'text': 'Santa Clara'},
#     {'answer_start': 403, 'text': 'Santa Clara'},
#     {'answer_start': 403, 'text': 'Santa Clara'}],
#    'question': 'What city did Super Bowl 50 take place in?',
#    'id': '56beace93aeaaa14008c91e1'},
#   {'answers': [{'answer_start': 693, 'text': 'Super Bowl L'},
#     {'answer_start': 704, 'text': 'L'},
#     {'answer_start': 693, 'text': 'Super Bowl L'}],
#    'question': 'If Roman numerals were used, what would Super Bowl 50 have been called?',
#    'id': '56beace93aeaaa14008c91e2'},
#   {'answers': [{'answer_start': 116, 'text': '2015'},
#     {'answer_start': 112, 'text': 'the 2015 season'},
#     {'answer_start': 116, 'text': '2015'}],
#    'question': 'Super Bowl 50 decided the NFL champion for what season?',
#    'id': '56beace93aeaaa14008c91e3'},
#   {'answers': [{'answer_start': 116, 'text': '2015'},
#     {'answer_start': 346, 'text': '2016'},
#     {'answer_start': 116, 'text': '2015'}],
#    'question': 'What year did the Denver Broncos secure a Super Bowl title for the third time?',
#    'id': '56bf10f43aeaaa14008c94fd'},
#   {'answers': [{'answer_start': 403, 'text': 'Santa Clara'},
#     {'answer_start': 403, 'text': 'Santa Clara'},
#     {'answer_start': 403, 'text': 'Santa Clara'}],
#    'question': 'What city did Super Bowl 50 take place in?',
#    'id': '56bf10f43aeaaa14008c94fe'},
#   {'answers': [{'answer_start': 355, 'text': "Levi's Stadium"},
#     {'answer_start': 355, 'text': "Levi's Stadium"},
#     {'answer_start': 355, 'text': "Levi's Stadium"}],
#    'question': 'What stadium did Super Bowl 50 take place in?',
#    'id': '56bf10f43aeaaa14008c94ff'},
#   {'answers': [{'answer_start': 267, 'text': '24–10'},
#     {'answer_start': 267, 'text': '24–10'},
#     {'answer_start': 267, 'text': '24–10'}],
#    'question': 'What was the final score of Super Bowl 50? ',
#    'id': '56bf10f43aeaaa14008c9500'},
#   {'answers': [{'answer_start': 334, 'text': 'February 7, 2016'},
#     {'answer_start': 334, 'text': 'February 7, 2016'},
#     {'answer_start': 334, 'text': 'February 7, 2016'}],
#    'question': 'What month, day and year did Super Bowl 50 take place? ',
#    'id': '56bf10f43aeaaa14008c9501'},
#   {'answers': [{'answer_start': 116, 'text': '2015'},
#     {'answer_start': 346, 'text': '2016'},
#     {'answer_start': 346, 'text': '2016'}],
#    'question': 'What year was Super Bowl 50?',
#    'id': '56d20362e7d4791d009025e8'},
#   {'answers': [{'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'}],
#    'question': 'What team was the AFC champion?',
#    'id': '56d20362e7d4791d009025e9'},
#   {'answers': [{'answer_start': 249, 'text': 'Carolina Panthers'},
#     {'answer_start': 249, 'text': 'Carolina Panthers'},
#     {'answer_start': 249, 'text': 'Carolina Panthers'}],
#    'question': 'What team was the NFC champion?',
#    'id': '56d20362e7d4791d009025ea'},
#   {'answers': [{'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'}],
#    'question': 'Who won Super Bowl 50?',
#    'id': '56d20362e7d4791d009025eb'},
#   {'answers': [{'answer_start': 116, 'text': '2015'},
#     {'answer_start': 112, 'text': 'the 2015 season'},
#     {'answer_start': 116, 'text': '2015'}],
#    'question': 'Super Bowl 50 determined the NFL champion for what season?',
#    'id': '56d600e31c85041400946eae'},
#   {'answers': [{'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'}],
#    'question': 'Which team won Super Bowl 50.',
#    'id': '56d600e31c85041400946eb0'},
#   {'answers': [{'answer_start': 403, 'text': 'Santa Clara, California.'},
#     {'answer_start': 355, 'text': "Levi's Stadium"},
#     {'answer_start': 355, 'text': "Levi's Stadium"}],
#    'question': 'Where was Super Bowl 50 held?',
#    'id': '56d600e31c85041400946eb1'},
#   {'answers': [{'answer_start': 0, 'text': 'Super Bowl'},
#     {'answer_start': 0, 'text': 'Super Bowl'},
#     {'answer_start': 0, 'text': 'Super Bowl'}],
#    'question': 'The name of the NFL championship game is?',
#    'id': '56d9895ddc89441400fdb50e'},
#   {'answers': [{'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'},
#     {'answer_start': 177, 'text': 'Denver Broncos'}],
#    'question': 'What 2015 NFL team one the AFC playoff?',
#    'id': '56d9895ddc89441400fdb510'}]}

# %%
import logging

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# %%
model_type="bert"
model_name= "bert-base-cased"

# %%
train_args = {
    'learning_rate': 3e-5,
    'num_train_epochs': 2,
    'max_seq_length': 384,
    'doc_stride': 128,
    'overwrite_output_dir': True,
    'reprocess_input_data': False,
    'train_batch_size': 6,
    'gradient_accumulation_steps': 8,
}

# %%
model = QuestionAnsweringModel(
    model_type,model_name, use_cuda=False, args=train_args
)
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
# !rm -rf outputs

# %%
model.train_model(train_data[:50], eval_data=test_data[:50])
# Out:
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 0 of 2:   0%|          | 0/41 [00:00<?, ?it/s]
# Running Epoch 1 of 2:   0%|          | 0/41 [00:00<?, ?it/s]
# (10, 5.612370938062668)

# %%
result, texts = model.eval_model(test_data[:50])
# Out:
# convert squad examples to features: 100%|██████████| 754/754 [00:08<00:00, 91.69it/s]
# add example index and unique id: 100%|██████████| 754/754 [00:00<00:00, 714690.44it/s]
# Running Evaluation:   0%|          | 0/97 [00:00<?, ?it/s]

# %%
result
# Out:
# {'correct': 5,
#  'similar': 181,
#  'incorrect': 568,
#  'eval_loss': -0.191129378269945}

# %%
texts
# Out:
# {'correct_text': {'56bebd713aeaaa14008c9330': '$2 million',
#   '56d9b43edc89441400fdb700': '$2 million',
#   '56bebec43aeaaa14008c9349': '25',
#   '56d7205e0d65d21400198391': 'Verizon',
#   '56d9bc13dc89441400fdb75f': 'Verizon'},
#  'similar_text': {'56be4db0acb8001400a502ec': {'truth': 'Denver Broncos',
#    'predicted': '(AFC) champion Denver Broncos defeated the National Football Conference',
#    'question': 'Which NFL team represented the AFC at Super Bowl 50?'},
#   '56be4db0acb8001400a502ef': {'truth': 'Denver Broncos',
#    'predicted': '(AFC) champion Denver Broncos defeated the National Football Conference',
#    'question': 'Which NFL team won Super Bowl 50?'},
#   '56beace93aeaaa14008c91df': {'truth': 'Denver Broncos',
#    'predicted': '(AFC) champion Denver Broncos defeated the National Football Conference',
#    'question': 'Who won Super Bowl 50?'},
#   '56beace93aeaaa14008c91e3': {'truth': '2015',
#    'predicted': '(NFL) for the 2015 season. The American Football',
#    'question': 'Super Bowl 50 decided the NFL champion for what season?'},
#   '56d20362e7d4791d009025e9': {'truth': 'Denver Broncos',
#    'predicted': '(AFC) champion Denver Broncos defeated the National Football',
#    'question': 'What team was the AFC champion?'},
#   '56d20362e7d4791d009025eb': {'truth': 'Denver Broncos',
#    'predicted': '(AFC) champion Denver Broncos defeated the National Football Conference',
#    'question': 'Who won Super Bowl 50?'},
#   '56d600e31c85041400946eae': {'truth': '2015',
#    'predicted': '(NFL) for the 2015 season. The American Football',
#    'question': 'Super Bowl 50 determined the NFL champion for what season?'},
#   '56d600e31c85041400946eb0': {'truth': 'Denver Broncos',
#    'predicted': '(AFC) champion Denver Broncos defeated the National Football Conference',
#    'question': 'Which team won Super Bowl 50.'},
#   '56d9895ddc89441400fdb510': {'truth': 'Denver Broncos',
#    'predicted': '(AFC) champion Denver Broncos defeated the National Football',
#    'question': 'What 2015 NFL team one the AFC playoff?'},
#   '56be4e1facb8001400a502fa': {'truth': '1995',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'What year was the Carolina Panthers franchise founded?'},
#   '56beaa4a3aeaaa14008c91c2': {'truth': 'Arizona Cardinals',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'What team did the Panthers defeat?'},
#   '56bead5a3aeaaa14008c91ea': {'truth': 'New England Patriots',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'Who lost to the Broncos in the AFC Championship?'},
#   '56bead5a3aeaaa14008c91eb': {'truth': 'New England Patriots',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'Who were the defending Super Bowl champions?'},
#   '56bf159b3aeaaa14008c9507': {'truth': '15–1',
#    'predicted': '15',
#    'question': 'What was the win/loss ratio in 2015 for the Carolina Panthers during their regular season?'},
#   '56bf159b3aeaaa14008c950a': {'truth': '4',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'How many teams have played in the Super Bowl eight times?'},
#   '56bf159b3aeaaa14008c950b': {'truth': 'New England Patriots',
#    'predicted': 'advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'Which team did not get a chance to defend their Super Bowl XLIX win in Super Bowl 50?'},
#   '56d2045de7d4791d009025f4': {'truth': 'Arizona Cardinals',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'Who did Carolina beat in the NFC championship game?'},
#   '56d2045de7d4791d009025f6': {'truth': 'New England Patriots',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'Who did Denver beat in the AFC championship?'},
#   '56d98a59dc89441400fdb52e': {'truth': '1995.',
#    'predicted': 'Most Valuable Player (MVP). They defeated the Arizona Cardinals 49–15 in the NFC Championship Game and advanced to their second Super Bowl appearance since the franchise was founded in 1995. The Broncos finished the regular season with a 12–4 record, and denied the New England Patriots a chance to defend their title from Super Bowl XL',
#    'question': 'What year did the Carolina Panthers form?'},
#   '56be4eafacb8001400a50303': {'truth': '2',
#    'predicted': 'five solo tackles, 2',
#    'question': 'How many fumbles did Von Miller force in Super Bowl 50?'},
#   '56beab833aeaaa14008c91d3': {'truth': 'five solo tackles',
#    'predicted': 'five solo tackles, 2',
#    'question': 'How many solo tackles did Von Miller make at Super Bowl 50?'},
#   '56bf17653aeaaa14008c9515': {'truth': '2',
#    'predicted': 'five solo tackles, 2',
#    'question': 'How many forced fumbles did Von Miller have during the Super Bowl 50 game?'},
#   '56d98b33dc89441400fdb53e': {'truth': 'five',
#    'predicted': 'five solo tackles, 2',
#    'question': 'How many tackles did Von Miller accomlish by himself in the game?'},
#   '56be5333acb8001400a5030c': {'truth': 'Coldplay',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': 'Which group headlined the Super Bowl 50 halftime show?'},
#   '56be5333acb8001400a5030d': {'truth': 'Beyoncé and Bruno Mars',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': 'Which performers joined the headliner during the Super Bowl 50 halftime show?'},
#   '56beaf5e3aeaaa14008c9201': {'truth': 'Coldplay',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': "Who was the main performer at this year's halftime show?"},
#   '56d2051ce7d4791d0090260a': {'truth': 'Coldplay',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': 'What band headlined half-time during Super Bowl 50?'},
#   '56d602631c85041400946eda': {'truth': 'Coldplay',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': 'Who headlined the halftime show for Super Bowl 50?'},
#   '56d602631c85041400946edb': {'truth': 'Beyoncé and Bruno Mars',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': 'Who were special guests for the Super Bowl halftime show?'},
#   '56d98c53dc89441400fdb545': {'truth': 'Coldplay',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': 'Who lead the Super Bowl 50 halftime performance?'},
#   '56d98c53dc89441400fdb548': {'truth': 'Bruno Mars',
#    'predicted': '30-second commercial during the game. The Super Bowl 50 halftime show was headlined by the British rock group Coldplay with special guest performers Beyoncé and Bruno Mars, who headlined the Super Bowl XL',
#    'question': 'What performer lead the Super Bowl XLVIII halftime show?'},
#   '56be53b8acb8001400a50314': {'truth': 'Roger Goodell',
#    'predicted': 'Roger Goodell stated that the league planned to make the 50th Super Bowl',
#    'question': 'Who was the NFL Commissioner in early 2012?'},
#   '56be53b8acb8001400a50315': {'truth': 'the 50th Super Bowl',
#    'predicted': 'Goodell stated that the league planned to make the 50th Super Bowl',
#    'question': 'Which Super Bowl did Roger Goodell speak about?'},
#   '56bf42f53aeaaa14008c95a3': {'truth': 'Roger Goodell',
#    'predicted': 'Roger Goodell stated that the league planned to make the 50th Super Bowl',
#    'question': 'Who was the commissioner of the NFL in 2012? '},
#   '56bf3c633aeaaa14008c9582': {'truth': 'Sun Life Stadium',
#    'predicted': "three sites: New Orleans' Mercedes-Benz Superdome, Miami's Sun Life Stadium",
#    'question': "What was the given name of Miami's stadium at the time of Super Bowl 50?"},
#   '56d6ee6e0d65d21400198254': {'truth': 'three',
#    'predicted': "three sites: New Orleans' Mercedes-Benz",
#    'question': "How many sites did the NFL narrow down Super Bowl 50's location to?"},
#   '56d6ee6e0d65d21400198255': {'truth': 'New Orleans',
#    'predicted': "three sites: New Orleans' Mercedes-Benz",
#    'question': 'One of the sites, Merceds-Benz Superdome, is located where?'},
#   '56be54bdacb8001400a50323': {'truth': '10',
#    'predicted': '2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX',
#    'question': 'How many times has the South Florida/Miami area hosted the Super Bowl?'},
#   '56be54bdacb8001400a50325': {'truth': '2010',
#    'predicted': '2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX',
#    'question': 'When was the most recent Super Bowl hosted in the South Florida/Miami area?'},
#   '56be54bdacb8001400a50326': {'truth': '1985',
#    'predicted': '2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX',
#    'question': 'When did the San Francisco Bay area last host the Super Bowl?'},
#   '56beb0f43aeaaa14008c921f': {'truth': '2010',
#    'predicted': '2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX',
#    'question': 'In what year was the Super Bowl last held in the Miami/South Florida area?'},
#   '56d6ef6a0d65d21400198260': {'truth': '1985',
#    'predicted': '2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX',
#    'question': 'Prior to this consideration, when did San Francisco last host a Super Bowl?'},
#   '56d98f0ddc89441400fdb559': {'truth': '10.',
#    'predicted': '2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX',
#    'question': 'How many times prios has the Sun Life Stadium had Super Bowls?'},
#   '56d98f0ddc89441400fdb55b': {'truth': '1985',
#    'predicted': '2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX',
#    'question': 'When was the last time San Francisco hosted a Super Bowl?'},
#   '56be5523acb8001400a5032e': {'truth': '2014',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': "When did Lev's Stadium open?"},
#   '56be5523acb8001400a5032f': {'truth': '$1.2 billion',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': "How much did it cost to build Levi's Stadium?"},
#   '56beb2153aeaaa14008c9227': {'truth': '$1.2 billion',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': "How much did it cost to build Levi's Stadium?"},
#   '56bf23363aeaaa14008c9530': {'truth': '2014',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': "When did Levi's stadium open to the public? "},
#   '56bf23363aeaaa14008c9531': {'truth': '$1.2 billion',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': 'How much did it cost to build the stadium where Super Bowl 50 was played?'},
#   '56d6f0770d65d21400198269': {'truth': '2014',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': "When did Levi's Stadium open?"},
#   '56d98fbfdc89441400fdb563': {'truth': '2014.',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': "When did Levi's Stadium open?"},
#   '56d98fbfdc89441400fdb564': {'truth': '$1.2 billion',
#    'predicted': '$1.2 billion stadium opened in 2014. It is the first Super Bowl held in the San Francisco Bay Area since Super Bowl XIX',
#    'question': "How much did Levi's Stadium cost?"},
#   '56beb2a03aeaaa14008c9232': {'truth': 'Super Bowl XLVIII',
#    'predicted': 'four teams to have made eight appearances in the Super Bowl. The Broncos made their second Super Bowl appearance in three years, having reached Super Bowl XLVIII, while the Panthers made their second Super Bowl appearance in franchise history, their other appearance being Super Bowl XX',
#    'question': 'What was the last Super Bowl the Broncos participated in?'},
#   '56bf28c73aeaaa14008c9539': {'truth': 'eight',
#    'predicted': 'four teams to have made eight appearances in the Super Bowl. The Broncos made their second Super Bowl appearance in three years, having reached Super Bowl XLVIII, while the Panthers made their second Super Bowl appearance in franchise history, their other appearance being Super Bowl XXX',
#    'question': 'What was the number of times the Denver Broncos played in a Super Bowl by the time they reached Super Bowl 50?'},
#   '56d6f1190d65d21400198274': {'truth': 'Super Bowl XLVIII',
#    'predicted': 'four teams to have made eight appearances in the Super Bowl. The Broncos made their second Super Bowl appearance in three years, having reached Super Bowl XLVIII, while the Panthers made their second Super Bowl appearance in franchise history, their other appearance being Super Bowl XX',
#    'question': 'Prior to Super Bowl 50, when were the Broncos last there?'},
#   '56d99179dc89441400fdb56d': {'truth': 'four',
#    'predicted': 'four teams to have made eight appearances in the Super Bowl. The Broncos made their second Super Bowl appearance in three years, having reached Super Bowl XLVIII, while the Panthers made their second Super Bowl appearance in franchise history, their other appearance being Super Bowl XX',
#    'question': 'How many teams up to Super Bowl 50 have been to the championship game eight times?'},
#   '56beb3083aeaaa14008c9241': {'truth': 'Kelvin Benjamin',
#    'predicted': 'ngelo Williams and losing top wide receiver Kelvin Benjamin to a torn ACL',
#    'question': 'What Panther tore his ACL in the preseason?'},
#   '56bf2afe3aeaaa14008c9547': {'truth': 'torn ACL',
#    'predicted': 'Kelvin Benjamin to a torn ACL',
#    'question': 'What injury did the Carolina Panthers lose Kelvin Benjamin to during their preseason?'},
#   '56beb3a03aeaaa14008c9247': {'truth': 'six',
#    'predicted': 'six Pro Bowl selections. Pro Bowl quarterback Cam Newton had one of his best seasons, throwing for 3,837 yards and rushing for 636',
#    'question': 'How many Pro Bowlers were on the Panthers offense?'},
#   '56d997cddc89441400fdb588': {'truth': '45',
#    'predicted': '636, while recording a career-high and league-leading 45 total',
#    'question': 'How many touchdowns did Newton get in the 2015 season?'},
#   '56beb4343aeaaa14008c925c': {'truth': '136',
#    'predicted': "6½ sacks. The Panthers line also featured veteran defensive end Jared Allen, a 5-time pro bowler who was the NFL's active career sack leader with 136",
#    'question': 'How many career sacks did Jared Allen have?'},
#   '56beb4e43aeaaa14008c9265': {'truth': 'Gary Kubiak',
#    'predicted': 'four years as Broncos head coach), and the hiring of Gary Kubiak as the new head coach. Under Kubiak, the Broncos planned to install a run-oriented offense with zone blocking to blend in with quarterback',
#    'question': 'Who is the head coach of the Broncos?'},
#   '56bf301c3aeaaa14008c954d': {'truth': 'four',
#    'predicted': 'four years as Broncos head coach',
#    'question': 'How many years was John Fox the head coach of the Denver Broncos?'},
#   '56d6f4030d65d2140019829e': {'truth': 'four',
#    'predicted': 'four years as Broncos head coach',
#    'question': 'How many games did the Broncos lose during their regular 2015 season?'},
#   '56beb57b3aeaaa14008c9279': {'truth': '67.9',
#    'predicted': '67.9 passer rating, throwing for 2,249 yards and nine touchdowns, with 17 interceptions. In contrast, Osweiler threw for 1',
#    'question': "What was Peyton Manning's passer rating for the season?"},
#   '56beb57b3aeaaa14008c927d': {'truth': '10',
#    'predicted': '7 yards, 10 touchdowns and six interceptions for a rating of 86.4. Veteran receiver Demaryius Thomas led the team with 105',
#    'question': 'How many touchdowns did Brock Osweiler throw in the season?'},
#   '56bf38383aeaaa14008c956b': {'truth': '67.9',
#    'predicted': '67.9 passer rating, throwing for 2,249 yards and nine touchdowns, with 17 interceptions. In contrast, Osweiler threw for 1',
#    'question': 'What was the passer rating for Peyton Manning that he finished out with for the season? '},
#   '56d6fe0b0d65d214001982a7': {'truth': '5',
#    'predicted': '105 receptions for 1',
#    'question': 'How many touchdowns did Ronnie Hillman make?'},
#   '56d99c44dc89441400fdb5d6': {'truth': '67.9',
#    'predicted': '67.9 passer rating, throwing for 2,249 yards and nine touchdowns, with 17 interceptions. In contrast, Osweiler threw for 1',
#    'question': "What was Manning's passer rating for the 2015 season?"},
#   '56beb6533aeaaa14008c928d': {'truth': '4,530',
#    'predicted': '4,530) for the first time in franchise history, and fourth in points allowed (296',
#    'question': "How many yards did the Broncos' defense give up?"},
#   '56d6fea90d65d214001982ae': {'truth': '296',
#    'predicted': '4,530) for the first time in franchise history, and fourth in points allowed (296',
#    'question': 'How many points did the Broncos defense allow their opponents to get?'},
#   '56beb6f23aeaaa14008c92a2': {'truth': 'Arizona Cardinals',
#    'predicted': '31–0 halftime lead and then holding off a furious second half comeback attempt to win 31–24, avenging their elimination from a year earlier. The Panthers then blew out the Arizona Cardinals in the NFC Championship',
#    'question': 'Who did the Panthers face in the NFC Championship Game?'},
#   '56beb6f23aeaaa14008c92a3': {'truth': '487',
#    'predicted': '7',
#    'question': 'How many total yards did the Panthers have in the NFC Championship?'},
#   '56bf34293aeaaa14008c955b': {'truth': '487',
#    'predicted': '7',
#    'question': 'How many yards did the Carolina Panthers gain in the 487 in the NFC Championship Game?'},
#   '56d99e78dc89441400fdb61a': {'truth': '487',
#    'predicted': '7',
#    'question': 'How many yards did the Panthers get for the division championshipt game?'},
#   '56beb7953aeaaa14008c92ac': {'truth': '11',
#    'predicted': '11 points in the final three minutes of the game. They then beat the defending Super Bowl XLIX',
#    'question': 'How many points did the Broncos score in the last three minutes of the game versus Pittsburgh?'},
#   '56d7018a0d65d214001982c3': {'truth': '11',
#    'predicted': '11 points in the final three minutes of the game. They then beat the defending Super Bowl',
#    'question': 'How many points did the Broncos score in the final three minutes of the Pittsburgh game?'},
#   '56beb7fd3aeaaa14008c92b7': {'truth': 'three',
#    'predicted': 'three ACL',
#    'question': 'How many times had Thomas Davis torn his ACL in his career?'},
#   '56d703d10d65d214001982d6': {'truth': 'three',
#    'predicted': 'three ACL',
#    'question': 'How many ACL injuries has Thomas Davis had during his career?'},
#   '56beb86b3aeaaa14008c92c1': {'truth': 'Broncos',
#    'predicted': 'John Elway, who led the Broncos to victory in Super Bowl XXXII',
#    'question': 'Who did John Elway play for in Super Bowl XXXIII?'},
#   '56bf3fd53aeaaa14008c9591': {'truth': 'Broncos',
#    'predicted': 'the Broncos to victory in Super Bowl XXXII',
#    'question': 'What team was the winner of Super Bowl XXXIII?'},
#   '56d704430d65d214001982e2': {'truth': 'Super Bowl XXXIII',
#    'predicted': 'the Broncos to victory in Super Bowl XXXIII at age 38',
#    'question': 'Which Super Bowl did Elway win at 38 years old?'},
#   '56bf41013aeaaa14008c959b': {'truth': 'Manning',
#    'predicted': '48 days (Manning was 39',
#    'question': 'Who was considered to be the first choice in the NFL draft of 1998?'},
#   '56beba103aeaaa14008c92e8': {'truth': 'Baltimore Ravens',
#    'predicted': "s Stadium's field was of a high enough quality to host a Super Bowl; during the inaugural season, the field had to be re-sodded multiple times due to various issues, and during a week 6 game earlier in the 2015 season, a portion of the turf collapsed under Baltimore Ravens",
#    'question': 'What team did Justin Tucker play for?'},
#   '56bebad93aeaaa14008c92fd': {'truth': 'Super Bowl XXXIII',
#    'predicted': 'XX',
#    'question': "What was Elway's final game as the Denver quarterback?"},
#   '56bf48cc3aeaaa14008c95ab': {'truth': 'Super Bowl XXXIII',
#    'predicted': 'XX',
#    'question': 'What was the last game that Elway played as a quarterback for Denver?'},
#   '56d9a637dc89441400fdb697': {'truth': 'Super Bowl XXXIII',
#    'predicted': 'XX',
#    'question': 'What was th elast Super Bowl where the Broncos wore white uniforms?'},
#   '56d9a637dc89441400fdb698': {'truth': 'blue',
#    'predicted': 'Denver QB, when they defeated the Atlanta Falcons 34–19. In their only other Super Bowl win in Super Bowl XXXII, Denver wore blue jerseys, which was their primary color at the time. They also lost Super Bowl XX',
#    'question': 'What was the color of the jerseys in Super Bowl XXXII when Elway was quarterback?'},
#   '56bebb293aeaaa14008c9304': {'truth': 'Stanford University',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': "At what university's facility did the Broncos practice?"},
#   '56bebb293aeaaa14008c9305': {'truth': 'San Jose',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': "In what city's Marriott did the Panthers stay?"},
#   '56bebb293aeaaa14008c9306': {'truth': 'Santa Clara',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': "In what city's Marriott did the Broncos stay?"},
#   '56bf49993aeaaa14008c95b5': {'truth': 'San Jose Marriott',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'What hotel did the Panthers stay in during Super Bowl 50? '},
#   '56bf49993aeaaa14008c95b6': {'truth': 'Santa Clara Marriott',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'What was the name of the hotel the Panthers chose to stay in during Super Bowl 50?'},
#   '56bf49993aeaaa14008c95b8': {'truth': 'Stanford University',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'Where did the Broncos practice at for Super Bowl 50?'},
#   '56d70d240d65d21400198327': {'truth': 'San Jose Marriott.',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'Which hotel did the Panthers stay at for the Super Bowl?'},
#   '56d70d240d65d21400198328': {'truth': 'Stanford University',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'Where did the Broncos practice for the Super Bowl?'},
#   '56d9a6b4dc89441400fdb6a0': {'truth': 'San Jose',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'Where was the practice place the Panthers used for the Super Bowl?'},
#   '56d9a6b4dc89441400fdb6a1': {'truth': 'San Jose Marriott.',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'Where hotel did the Panthers stay at?'},
#   '56d9a6b4dc89441400fdb6a2': {'truth': 'Stanford University',
#    'predicted': 'the San Jose Marriott. The Broncos practiced at Stanford University and stayed at the Santa Clara Marriott',
#    'question': 'Where did the Broncos practice for the Super Bowl?'},
#   '56bebbbf3aeaaa14008c9316': {'truth': 'Super Bowl V',
#    'predicted': 'Roman numerals, a practice established at Super Bowl V, would be temporarily suspended, and that the game would be named using Arabic numerals as Super Bowl 50 as opposed to Super Bowl',
#    'question': 'What was the first Super Bowl branded with Roman numerals?'},
#   '56d70daa0d65d21400198333': {'truth': 'Arabic numerals',
#    'predicted': 'numerals, a practice established at Super Bowl V, would be temporarily suspended, and that the game would be named using Arabic numerals as Super Bowl',
#    'question': 'Rather than Roman numerals, what did the NFL decide to use?'},
#   '56d70daa0d65d21400198334': {'truth': 'L.',
#    'predicted': 'numerals, a practice established at Super Bowl V, would be temporarily suspended, and that the game would be named using Arabic numerals as Super Bowl 50 as opposed to Super Bowl L. The use of Roman numerals will be reinstated for Super Bowl',
#    'question': 'What is the Roman numeral for 50?'},
#   '56d9a7addc89441400fdb6a8': {'truth': 'Arabic',
#    'predicted': 'Roman numerals, a practice established at Super Bowl V, would be temporarily suspended, and that the game would be named using Arabic numerals as Super Bowl',
#    'question': 'What type of numeral did the latest Super Bowl use to designate the game number?'},
#   '56bebc383aeaaa14008c931f': {'truth': 'gold',
#    'predicted': '50-yard line on fields was colored gold, and beginning on week 7, all sideline jackets and hats featured gold-trimmed logos. Gold footballs were given to each high school that has had a player or coach appear in the Super Bowl, and "homecoming" events were also held by Super Bowl',
#    'question': 'What color was featured in promotions related to Super Bowl 50?'},
#   '56bebc383aeaaa14008c9320': {'truth': 'week 7',
#    'predicted': '50-yard line on fields was colored gold, and beginning on week 7, all sideline jackets and hats featured gold-trimmed',
#    'question': 'When did sideline jackets and hats start to feature gold-trimmed logos?'},
#   '56bebc383aeaaa14008c9321': {'truth': '50',
#    'predicted': '50-yard line on fields was colored gold, and beginning on week 7, all sideline jackets and hats featured gold-trimmed logos. Gold footballs were given to each high school that has had a player or coach appear in the Super Bowl, and "homecoming" events were also held by Super Bowl',
#    'question': 'What yard marker on the field was painted gold?'},
#   '56bf52483aeaaa14008c95c7': {'truth': 'gold',
#    'predicted': '50-yard line on fields was colored gold, and beginning on week 7, all sideline jackets and hats featured gold-trimmed logos. Gold footballs were given to each high school that has had a player or coach appear in the Super Bowl, and "homecoming" events were also held by Super Bowl',
#    'question': "What color was used to create the 50-yard line in Levi's Stadium for the season leading up to the Super Bowl 50 game?"},
#   '56bf52483aeaaa14008c95c8': {'truth': 'gold',
#    'predicted': '50-yard line on fields was colored gold, and beginning on week 7, all sideline jackets and hats featured gold-trimmed logos. Gold footballs were given to each high school that has had a player or coach appear in the Super Bowl, and "homecoming" events were also held by Super Bowl',
#    'question': 'What color were the footballs handed out to a variety of high schools, leading up to Super Bowl 50?'},
#   '56d70e570d65d2140019833e': {'truth': 'Gold footballs',
#    'predicted': '50-yard line on fields was colored gold, and beginning on week 7, all sideline jackets and hats featured gold-trimmed logos. Gold footballs were given to each high school that has had a player or coach appear in the Super Bowl, and "homecoming" events were also held by Super Bowl',
#    'question': 'What was given to high schools where former students went on to play or coach in a Super Bowl?'},
#   '56d9b01fdc89441400fdb6d4': {'truth': 'gold',
#    'predicted': '50-yard line on fields was colored gold, and beginning on week 7, all sideline jackets and hats featured gold-trimmed logos. Gold footballs were given to each high school that has had a player or coach appear in the Super Bowl, and "homecoming" events were also held by Super Bowl',
#    'question': 'Since this was the 50th one, what was the theme color for the Super Bowl?'},
#   '56d9b389dc89441400fdb6ed': {'truth': 'More than 1 million',
#    'predicted': 'than 1',
#    'question': 'How many people are likely to visit Justin Herman Plaza during the week of the Super Bowl?'},
#   '56bf555e3aeaaa14008c95d3': {'truth': '$2 million',
#    'predicted': '$2',
#    'question': 'How much money was spent on other festivities in the Bay area to help celebrate the coming Super Bowl 50?'},
#   '56bebde53aeaaa14008c9335': {'truth': 'Monday',
#    'predicted': 'Monday evening and re-branded as Super Bowl Opening Night. The event was held on February 1',
#    'question': 'On what day was Super Bowl Opening Night held?'},
#   '56d71bd80d65d2140019835e': {'truth': 'the Tuesday afternoon prior to the game',
#    'predicted': 's media day, which was typically held on the Tuesday afternoon prior to the game, was moved to the Monday evening and re-branded as Super Bowl Opening Night. The event was held on February 1',
#    'question': "When is the game's media day usually held?"},
#   '56d71bd80d65d21400198360': {'truth': 'Super Bowl Opening Night.',
#    'predicted': 'Monday evening and re-branded as Super Bowl Opening Night. The event was held on February 1',
#    'question': 'What new name was given to the media day?'},
#   '56bebe873aeaaa14008c9340': {'truth': '$40 million',
#    'predicted': '40',
#    'question': 'How much money has been raised by the host committee?'},
#   '56bf59523aeaaa14008c95e4': {'truth': 'over $40 million',
#    'predicted': '40',
#    'question': 'How much money did the committee raise?'},
#   '56d9b5ffdc89441400fdb721': {'truth': 'over $40 million',
#    'predicted': '40',
#    'question': 'According to the text, how much money did the Host Committee raise?'},
#   '56bf5abc3aeaaa14008c95e9': {'truth': '25 percent',
#    'predicted': '25',
#    'question': 'What percentage of funds were given as charitable funds to causes in and around San Francisco?'},
#   '56d71d150d65d2140019836f': {'truth': '25 percent',
#    'predicted': '25',
#    'question': 'How many will the host committee dedicate to local charities?'},
#   '56d9b6a3dc89441400fdb72f': {'truth': '25 percent',
#    'predicted': '25',
#    'question': 'What percentage of money raised was earmarked for causes in the San Francisco area?'},
#   '56bec0353aeaaa14008c934f': {'truth': '66',
#    'predicted': '33 lb (15 kg) for a total of 66 lb (30',
#    'question': 'What will the "50" given to the Super Bowl winner weigh in pounds?'},
#   '56bec0dd3aeaaa14008c9358': {'truth': 'Phil Simms',
#    'predicted': 'tz and Phil Simms called the contest, with Tracy Wolfson',
#    'question': "Who, with Jim Nantz, was a member of the game's lead broadcast team?"},
#   '56bf5e7b3aeaaa14008c95f7': {'truth': 'three',
#    'predicted': "three main broadcast television partners of the NFL. The network's lead broadcast team of Jim Nantz and Phil Simms called the contest, with Tracy Wolfson",
#    'question': 'How many different TV networks are considered to be the principal partners, when it comes to broadcasting NFL events?'},
#   '56bf5e7b3aeaaa14008c95fb': {'truth': 'sidelines',
#    'predicted': 'Evan Washburn on the sidelines. CBS introduced new features during the telecast, including pylon cameras and microphones along with EyeVision 360—an array of 36 cameras along the upper deck that can be used to provide a 360-degree view of plays and "bullet time" effects. (An earlier version of EyeVision was last used in Super Bowl XXX',
#    'question': 'Where was Evan Washburn located while announcing during the game?'},
#   '56d71ed50d65d2140019837d': {'truth': 'three',
#    'predicted': "three main broadcast television partners of the NFL. The network's lead broadcast team of Jim Nantz and Phil Simms called the contest, with Tracy Wolfson",
#    'question': 'How many broadcast television partners does the NFL have?'},
#   '56d9b7dcdc89441400fdb744': {'truth': 'cameras',
#    'predicted': 'Vision 360—an array of 36 cameras along the upper deck that can be used to provide a 360-degree view of plays and "bullet time" effects. (An earlier version of EyeVision was last used in Super Bowl XXX',
#    'question': 'What was put on pylons for Super Bowl 50?'},
#   '56bec2013aeaaa14008c9375': {'truth': '10',
#    'predicted': '10, Xbox One and other digital media players (such as Chromecast and Roku). Due to Verizon Communications exclusivity, streaming on smartphones was only provided to Verizon',
#    'question': 'What version of Windows supported the CBS sports app?'},
#   '56bf6e7a3aeaaa14008c9621': {'truth': 'Verizon Wireless customers',
#    'predicted': 'Verizon',
#    'question': 'Which smartphone customers were the only people who could stream the game on their phones?'},
#   '56bec2573aeaaa14008c937b': {'truth': 'The Late Show with Stephen Colbert',
#    'predicted': 'night talk shows as its lead-out programs for Super Bowl 50, beginning with a special episode of The Late Show with Stephen Colbert following the game. Following a break for late local programming, CBS also aired a special episode of The Late Late',
#    'question': 'What talk show followed immediately after Super Bowl 50 on CBS?'},
#   '56bec2573aeaaa14008c937c': {'truth': 'The Late Late Show with James Corden',
#    'predicted': 'The Late',
#    'question': 'What show aired on CBS after late local programming?'},
#   '56bf6f743aeaaa14008c9631': {'truth': 'The Late Show with Stephen Colbert',
#    'predicted': 'The Late',
#    'question': 'Which late night comedy host show played immediately after Super Bowl 50 ended?'},
#   '56d720c70d65d21400198397': {'truth': 'late local programming',
#    'predicted': 'Stephen Colbert following the game. Following a break for late local programming, CBS also aired a special episode of The Late Late',
#    'question': 'What followed The Late Show with Stephen Colbert?'},
#   '56bec3153aeaaa14008c9389': {'truth': '$5,000,000',
#    'predicted': '5,000',
#    'question': 'What was the base rate for a 30-second ad during Super Bowl 50?'},
#   '56bf717d3aeaaa14008c9635': {'truth': '$5,000,000',
#    'predicted': '5,000',
#    'question': 'What was the starting cost for a TV commercial lasting 30 seconds and airing during Super Bowl 50?'},
#   '56bec4343aeaaa14008c93a9': {'truth': 'Jason Bourne',
#    'predicted': 'for Gods of Egypt, Paramount paid for Teenage Mutant Ninja Turtles: Out of the Shadows and 10 Cloverfield Lane, Universal paid for The Secret Life of Pets and the debut trailer for Jason Bourne and Disney paid for Captain America: Civil War, The Jungle Book',
#    'question': 'What Universal trailer debuted during the Super Bowl?'},
#   '56bec4343aeaaa14008c93aa': {'truth': 'Gods of Egypt',
#    'predicted': 'for Gods of Egypt, Paramount paid for Teenage Mutant Ninja Turtles: Out of the Shadows and 10 Cloverfield Lane, Universal paid for The Secret Life of Pets and the debut trailer for Jason Bourne and Disney paid for Captain America: Civil War, The Jungle Book',
#    'question': 'What Lionsgate trailer was shown during the Super Bowl?'},
#   '56bec4343aeaaa14008c93ab': {'truth': 'Teenage Mutant Ninja Turtles: Out of the Shadows',
#    'predicted': 'for Gods of Egypt, Paramount paid for Teenage Mutant Ninja Turtles: Out of the Shadows and 10 Cloverfield Lane, Universal paid for The Secret Life of Pets and the debut trailer for Jason Bourne and Disney paid for Captain America: Civil War, The Jungle Book',
#    'question': 'Along with 10 Cloverfield Lane, what Paramount trailer appeared during the Super Bowl?'},
#   '56d723560d65d214001983ac': {'truth': 'Gods of Egypt',
#    'predicted': 'for Gods of Egypt, Paramount paid for Teenage Mutant Ninja Turtles: Out of the Shadows and 10 Cloverfield Lane, Universal paid for The Secret Life of Pets and the debut trailer for Jason Bourne and Disney paid for Captain America: Civil War, The Jungle Book',
#    'question': 'What film did Lionsgate pay to have the trailer aired during the Super Bowl?'},
#   '56d723560d65d214001983ae': {'truth': 'Jason Bourne',
#    'predicted': 'for Gods of Egypt, Paramount paid for Teenage Mutant Ninja Turtles: Out of the Shadows and 10 Cloverfield Lane, Universal paid for The Secret Life of Pets and the debut trailer for Jason Bourne and Disney paid for Captain America: Civil War, The Jungle Book',
#    'question': 'Universal Paid for The Secret Life of Pets and which other film trailer?'},
#   '56d723560d65d214001983af': {'truth': 'Captain America: Civil War',
#    'predicted': 'for Gods of Egypt, Paramount paid for Teenage Mutant Ninja Turtles: Out of the Shadows and 10 Cloverfield Lane, Universal paid for The Secret Life of Pets and the debut trailer for Jason Bourne and Disney paid for Captain America: Civil War, The Jungle Book',
#    'question': 'Disney paid for The Jungle Book, Alice Through the Looking Glass, and which other film trailer to be aired during the game?'},
#   '56bec4a33aeaaa14008c93b2': {'truth': 'Kevin Harlan',
#    'predicted': 'carry the game throughout North America, with Kevin Harlan as play-by-play announcer, Boomer Esiason',
#    'question': 'Who did play-by-play on Westwood One?'},
#   '56bf738b3aeaaa14008c9656': {'truth': 'Kevin Harlan',
#    'predicted': 'carry the game throughout North America, with Kevin Harlan as play-by-play announcer, Boomer Esiason',
#    'question': 'Who announced the game play-by-play for Super Bowl 50?'},
#   '56d723ad0d65d214001983b5': {'truth': 'Kevin Harlan',
#    'predicted': 'carry the game throughout North America, with Kevin Harlan as play-by-play announcer, Boomer Esiason',
#    'question': 'Who is the play-by-play announcer for the game?'},
#   '56d9c049dc89441400fdb78e': {'truth': 'Kevin Harlan',
#    'predicted': 'carry the game throughout North America, with Kevin Harlan as play-by-play announcer, Boomer Esiason',
#    'question': "Who was the announcer for Westwood One's Super Bowl 50 coverage?"},
#   '56d9c049dc89441400fdb792': {'truth': 'North America',
#    'predicted': 'carry the game throughout North America, with Kevin Harlan as play-by-play announcer, Boomer Esiason',
#    'question': 'What area did the Westwood One broadcast cover?'},
#   '56bec5233aeaaa14008c93d1': {'truth': '1110 AM',
#    'predicted': '1110 AM) will carry the game, with Mick Mixon on play-by-play and Eugene Robinson and Jim Szoke on color commentary. WBT will also simulcast the game on its sister station WBT-FM (99.3 FM), which is based in Chester, South Carolina',
#    'question': 'What is the frequency of the radio station WBT in North Carolina?'},
#   '56bec5233aeaaa14008c93d2': {'truth': 'Chester, South Carolina',
#    'predicted': '1110 AM) will carry the game, with Mick Mixon on play-by-play and Eugene Robinson and Jim Szoke on color commentary. WBT will also simulcast the game on its sister station WBT-FM (99.3 FM), which is based in Chester, South Carolina',
#    'question': 'In what city is WBT-FM located?'},
#   '56bec5233aeaaa14008c93d3': {'truth': 'Mick Mixon',
#    'predicted': '1110 AM) will carry the game, with Mick Mixon on play-by-play and Eugene Robinson and Jim Szoke on color commentary. WBT will also simulcast the game on its sister station WBT-FM (99.3 FM), which is based in Chester, South Carolina',
#    'question': 'Who did play-by-play for the WBT broadcast?'},
#   '56d724620d65d214001983c0': {'truth': 'WBT',
#    'predicted': '1110 AM) will carry the game, with Mick Mixon on play-by-play and Eugene Robinson and Jim Szoke on color commentary. WBT will also simulcast the game on its sister station WBT-FM (99.3 FM), which is based in Chester, South Carolina',
#    'question': 'Which station covered the game for North Carolina?'},
#   '56d724620d65d214001983c1': {'truth': 'Mick Mixon',
#    'predicted': '1110 AM) will carry the game, with Mick Mixon on play-by-play and Eugene Robinson and Jim Szoke on color commentary. WBT will also simulcast the game on its sister station WBT-FM (99.3 FM), which is based in Chester, South Carolina',
#    'question': 'Who handled the play-by-play for WBT?'},
#   '56d9c203dc89441400fdb7a3': {'truth': 'WBT-FM (99.3 FM)',
#    'predicted': '1110 AM) will carry the game, with Mick Mixon on play-by-play and Eugene Robinson and Jim Szoke on color commentary. WBT will also simulcast the game on its sister station WBT-FM (99.3 FM), which is based in Chester, South Carolina',
#    'question': 'What radio station in South Carolina carried the Super Bowl 50 game?'},
#   '56bec5ff3aeaaa14008c93e3': {'truth': 'BBC Radio 5',
#    'predicted': 'United Kingdom, BBC Radio 5',
#    'question': 'What BBC radio station will carry the game in the United Kingdom?'},
#   '56d724ea0d65d214001983c8': {'truth': 'BBC',
#    'predicted': 'United Kingdom, BBC Radio 5',
#    'question': 'What British TV network will carry the Super Bowl?'},
#   '56bec6573aeaaa14008c93e9': {'truth': 'Bart Starr',
#    'predicted': '39 of the 43 previous Super Bowl Most Valuable Players. Bart Starr (MVP of Super Bowls I and II',
#    'question': 'Who was the Most Valuable Player of Super Bowl II?'},
#   '56bec6573aeaaa14008c93eb': {'truth': 'Peyton Manning',
#    'predicted': '39 of the 43 previous Super Bowl Most Valuable Players. Bart Starr (MVP of Super Bowls I and II) and Chuck Howley (MVP of Super Bowl V) appeared via video, while Peyton Manning (MVP of Super Bowl XL',
#    'question': 'Who was the Most Valuable Player of Super Bowl XLI?'},
#   '56d7251d0d65d214001983cc': {'truth': '39',
#    'predicted': '39 of the 43 previous Super Bowl Most Valuable Players. Bart Starr (MVP of Super Bowls I and II',
#    'question': 'How many of the prior Super Bowl MVPs appeared together at the pregame show?'},
#   '56d9c3a6dc89441400fdb7b4': {'truth': '43',
#    'predicted': '39 of the 43 previous Super Bowl Most Valuable Players. Bart Starr (MVP of Super Bowls I and II',
#    'question': 'How many players have been awarded the Most Valuable Player distinction for the Super Bowl?'},
#   '56d9c3a6dc89441400fdb7b5': {'truth': '39',
#    'predicted': '39 of the 43 previous Super Bowl Most Valuable Players. Bart Starr (MVP of Super Bowls I and II',
#    'question': 'How many former MVP honorees were present for a pregame ceremony?'},
#   '56d9c3a6dc89441400fdb7b6': {'truth': 'Bart Starr',
#    'predicted': '39 of the 43 previous Super Bowl Most Valuable Players. Bart Starr (MVP of Super Bowls I and II',
#    'question': 'Who was the MVP of Super Bowl I and II?'},
#   '56d9c3a6dc89441400fdb7b7': {'truth': 'Peyton Manning',
#    'predicted': '39 of the 43 previous Super Bowl Most Valuable Players. Bart Starr (MVP of Super Bowls I and II) and Chuck Howley (MVP of Super Bowl V) appeared via video, while Peyton Manning (MVP of Super Bowl XL',
#    'question': 'Who was the MVP of Super Bowl XLI?'},
#   '56d20650e7d4791d00902614': {'truth': 'Lady Gaga',
#    'predicted': 'Lady',
#    'question': 'Who sang the national anthem?'},
#   '56d7253b0d65d214001983d4': {'truth': 'Lady Gaga',
#    'predicted': 'Lady',
#    'question': 'Who did the National Anthem at Super Bowl 50?'},
#   '56d9c455dc89441400fdb7c4': {'truth': 'Lady Gaga',
#    'predicted': 'Lady',
#    'question': 'Who did the Super Bowl 50 National Anthem?'},
#   '56d725790d65d214001983da': {'truth': 'Pepsi',
#    'predicted': '7, 2016, Pepsi confirmed to the Associated Press that Beyoncé, who headlined the Super Bowl XL',
#    'question': 'What company confirmed that Beyoncé would participate in the Super Bowl 50 halftime show?'},
#   '56d9c551dc89441400fdb7d1': {'truth': 'Beyoncé',
#    'predicted': '2016, Pepsi confirmed to the Associated Press that Beyoncé, who headlined the Super Bowl XL',
#    'question': 'On January 7, 2016, it was confirmed that which start would join Coldplay for the halftime show?'},
#   '56bec7a63aeaaa14008c9417': {'truth': 'Denver',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled Anderson for a 1-yard gain on third down, forcing Denver to settle for a 3–0',
#    'question': 'What team received the opening kickoff?'},
#   '56d9c5e7dc89441400fdb7d8': {'truth': 'Denver',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled Anderson for a 1-yard gain on third down, forcing Denver to settle for a 3–0',
#    'question': 'Which team had the first kickoff?'},
#   '56bec8243aeaaa14008c942e': {'truth': 'Malik Jackson',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Which player recovered possession of the ball in the end zone?'},
#   '56d728e00d65d2140019841f': {'truth': 'Malik Jackson',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Who received the ball that cam Newton lost during a tackle to make it a Denver touchdown?'},
#   '56d9c660dc89441400fdb7e9': {'truth': 'Malik Jackson',
# ...
#   '56d9c551dc89441400fdb7d3': {'truth': 'Bruno Mars',
#    'predicted': '7, 2016, Pepsi confirmed to the Associated Press that Beyoncé, who headlined the Super Bowl XL',
#    'question': 'What other former halftime show performer joined Coldplay and Beyoncé for the Super Bowl 50 halftime show?'},
#   '56bec7a63aeaaa14008c9418': {'truth': 'Andre Caldwell',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled Anderson for a 1-yard gain on third down, forcing Denver to settle for a 3–0 lead on a Brandon Mc',
#    'question': 'Who was at the receiving end of a 22-yard pass from Peyton Manning?'},
#   '56bec7a63aeaaa14008c9419': {'truth': 'Ronnie Hillman',
#    'predicted': '3',
#    'question': 'Who lost 3 yards on a tackle by Shaq Thompson?'},
#   '56bec7a63aeaaa14008c941a': {'truth': 'Brandon McManus',
#    'predicted': '3–0',
#    'question': 'Who kicked a field goal for Denver?'},
#   '56bec7a63aeaaa14008c941b': {'truth': 'C. J. Anderson',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled Anderson for a 1-yard gain on third down, forcing Denver to settle for a 3–0',
#    'question': 'Who ran the ball twice for 20 yards on this drive?'},
#   '56d728a10d65d21400198413': {'truth': '18',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled Anderson for a 1-yard gain on third down, forcing Denver to settle for a 3–0',
#    'question': 'How many yards was the pass on the first drive?'},
#   '56d728a10d65d21400198414': {'truth': 'Shaq Thompson',
#    'predicted': '3',
#    'question': 'Who tackled Ronnie Hillman for a loss of yardage?'},
#   '56d728a10d65d21400198415': {'truth': 'Brandon McManus',
#    'predicted': '3–0 lead on a Brandon Mc',
#    'question': 'Who kicked the field goal for Denver on the first drive of Super Bowl 50?'},
#   '56d728a10d65d21400198416': {'truth': 'a deficit.',
#    'predicted': '3–0 lead on a Brandon Mc',
#    'question': 'This was the first time that the Carolina team faced what in the post season?'},
#   '56d9c5e7dc89441400fdb7d9': {'truth': 'Owen Daniels',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled',
#    'question': 'Who did Peyton Manning complete an 18 yard pass to on the opening drive?'},
#   '56d9c5e7dc89441400fdb7da': {'truth': 'C. J. Anderson',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled Anderson for a 1-yard gain on third down, forcing Denver to settle for a 3–0',
#    'question': 'Which Denver player took the ball to the Panthers 14 yard line?'},
#   '56d9c5e7dc89441400fdb7db': {'truth': 'Brandon McManus',
#    'predicted': '3-yard loss. Then after an incompletion, Thomas Davis tackled Anderson for a 1-yard gain on third down, forcing Denver to settle for a 3–0',
#    'question': 'Who scored the first points for Denver?'},
#   '56d9c5e7dc89441400fdb7dc': {'truth': 'a deficit.',
#    'predicted': '3–0 lead on a Brandon Mc',
#    'question': 'What did Carolina face in the opening drive that they had not faced the entire postseason?'},
#   '56bec8243aeaaa14008c942b': {'truth': 'Mike Carey',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Which former referee served as an analyst for CBS?'},
#   '56bec8243aeaaa14008c942c': {'truth': 'Cam Newton',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Whose pass to Jerricho Cotchery was ruled incomplete?'},
#   '56bec8243aeaaa14008c942d': {'truth': 'Von Miller',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XX',
#    'question': 'Who stripped the ball from Cam Newton while sacking him on this drive?'},
#   '56bec8243aeaaa14008c942f': {'truth': 'Super Bowl XXVIII',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XX',
#    'question': 'What Super Bowl was the last where a fumble was returned for a touchdown?'},
#   '56d728e00d65d2140019841c': {'truth': 'Jerricho Cotchery',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Who received the pass that was ruled incomplete and confirmed after a challenge?'},
#   '56d728e00d65d2140019841d': {'truth': 'Mike Carey',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'What analyst did not agree with the ruling of the incomplete pass?'},
#   '56d728e00d65d2140019841e': {'truth': 'Von Miller',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Who, according to the text, caused Cam Newton to lose the ball during a tackle?'},
#   '56d728e00d65d21400198420': {'truth': '1993',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'What year was the last time a fumble return touchdown like this occurred?'},
#   '56d9c660dc89441400fdb7e7': {'truth': 'Mike Carey',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Which retired ref disagreed with the outcome of the challenge of a incomplete pass?'},
#   '56d9c660dc89441400fdb7e8': {'truth': 'Von Miller',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XXVIII',
#    'question': 'Who sacked Newton a few plays after the challenge?'},
#   '56d9c660dc89441400fdb7ea': {'truth': 'Super Bowl XXVIII',
#    'predicted': 's hands while sacking him, and Malik Jackson recovered it in the end zone for a Broncos touchdown, giving the team a 10–0 lead. This was the first fumble return touchdown in a Super Bowl since Super Bowl XX',
#    'question': 'When is the last time a fumble return touchdown happened in a Super Bowl?'},
#   '56bec8a13aeaaa14008c9436': {'truth': 'Brad Nortman',
#    'predicted': '51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10–7 with 11:28',
#    'question': 'Who punted the ball for Carolina?'},
#   '56bec8a13aeaaa14008c9437': {'truth': '28',
#    'predicted': '73-yard scoring drive. Newton completed 4 of 4 passes for 51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10',
#    'question': "How many yards did Brad Nortman's punt travel?"},
#   '56bec8a13aeaaa14008c9438': {'truth': '61',
#    'predicted': '73-yard scoring drive. Newton completed 4 of 4 passes for 51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10',
#    'question': 'How many yards did Jordan Norwood return a punt to set the Super Bowl record?'},
#   '56bec8a13aeaaa14008c9439': {'truth': '33',
#    'predicted': '73-yard scoring drive. Newton completed 4 of 4 passes for 51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10',
#    'question': 'How many yards was the McManus field goal?'},
#   '56d729180d65d21400198428': {'truth': '11:28',
#    'predicted': '73-yard scoring drive. Newton completed 4 of 4 passes for 51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10',
#    'question': 'How much time was left in the quarter when Stewart got the touchdown?'},
#   '56d729180d65d21400198429': {'truth': 'Jordan Norwood',
#    'predicted': '51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10',
#    'question': 'Who got a 61-yard return when players thought he called for a fair catch but did not?'},
#   '56d729180d65d2140019842a': {'truth': '33',
#    'predicted': '51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10',
#    'question': 'How many yards was the field goal that made the score 13-7 in Super Bowl 50?'},
#   '56d9c6e0dc89441400fdb7f4': {'truth': 'field goal',
#    'predicted': '73-yard scoring drive. Newton completed 4 of 4 passes for 51 yards and rushed twice for 25 yards, while Jonathan Stewart finished the drive with a 1-yard touchdown run, cutting the score to 10',
#    'question': 'How did Denver score at the end of the drive?'},
#   '56bec9133aeaaa14008c9445': {'truth': 'Darian Stewart',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'Who tackled Mike Tolbert and caused a fumble?'},
#   '56bec9133aeaaa14008c9446': {'truth': 'linebacker',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'What position does Danny Trevathan play?'},
#   '56bec9133aeaaa14008c9448': {'truth': 'Newton',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'Who was sacked as the first half clock expired?'},
#   '56bec9133aeaaa14008c9449': {'truth': 'DeMarcus Ware',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'Who sacked Cam Newton at the end of the half?'},
#   '56d729ec0d65d21400198430': {'truth': 'Mike Tolbert',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'Who fumbled the ball when tackled by Darian Stewart?'},
#   '56d729ec0d65d21400198434': {'truth': 'DeMarcus Ware',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': "Who tackled the Carolina Panthers' quarterback just before the end of the first half?"},
#   '56d9c79edc89441400fdb804': {'truth': 'Mike Tolbert',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'Which fullback fumbled the ball after a Darian Stewart tackle?'},
#   '56d9c79edc89441400fdb805': {'truth': 'Danny Trevathan',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': "Who recovered Tolbert's fumble?"},
#   '56d9c79edc89441400fdb807': {'truth': 'punt',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'How did the drive end for the Panthers?'},
#   '56d9c79edc89441400fdb808': {'truth': 'DeMarcus Ware',
#    'predicted': '40-yard line. However, the Panthers soon took the ball back when defensive end Kony Ealy tipped a Manning pass to himself and then intercepted it, returning the ball 19 yards to the Panthers',
#    'question': 'Who sacked Newton with 11 seconds left in the first half?'},
#   '56bec98e3aeaaa14008c9455': {'truth': 'Ted Ginn Jr.',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'Who was on the receiving end of a 45-yard pass from Cam Newton?'},
#   '56bec98e3aeaaa14008c9456': {'truth': 'Graham Gano',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'Who missed a field goal for the Panthers?'},
#   '56bec98e3aeaaa14008c9458': {'truth': 'McManus',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'What kicker was successful on a 33-yard field goal?'},
#   '56bec98e3aeaaa14008c9459': {'truth': 'T. J. Ward',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'Who picked off Cam Newton and subsequently fumbled the ball?'},
#   '56d7282f0d65d21400198408': {'truth': 'Ted Ginn Jr.',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'Who did Newton complete a 45 yard pass to on the opening drive of the second half?'},
#   '56d7282f0d65d21400198409': {'truth': 'the uprights',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'What did Gano hit on his 44-yard field goal attempt?'},
#   '56d7282f0d65d2140019840a': {'truth': 'T. J. Ward.',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': "Which Broncos player intercepted Newton on the Panthers' next set of downs?"},
#   '56d7282f0d65d2140019840c': {'truth': 'Trevathan',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': "Who recovered Ward's fumble?"},
#   '56d9c92bdc89441400fdb80e': {'truth': 'Ted Ginn Jr.',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'Who did Newton get a pass to in the Panther starting plays of Super Bowl 50?'},
#   '56d9c92bdc89441400fdb80f': {'truth': '26-yard line',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'What yard line did the Broncos stop the Panthers on in their first offensive drive of Super Bowl 50?'},
#   '56d9c92bdc89441400fdb810': {'truth': 'Graham Gano',
#    'predicted': '44-yard field goal attempt. After the miss, Manning completed a pair of passes to Emmanuel Sanders for gains of 25',
#    'question': 'Who hit the goal post on a field goal attempt?'}}}

# %%
to_predict = [
    {
        "context": "Vin is a Mistborn of great power and skill.",
        "qas": [
            {
                "question": "What is Vin's speciality?",
                "id": "0",
            }
        ],
    }
]

# %%
answers, probabilities = model.predict(to_predict)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 169.36it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 8473.34it/s]
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Mistborn of great power', 'power', 'Mistborn of great power and skill', 'is a Mistborn of great power', 'skill', 'Mistborn of great power and', 'power and skill', 'Vin is a Mistborn of great power', 'Mi', 'power and', 'is a Mistborn of great power and skill', 'Vin', 'stborn of great power', 'is a Mistborn of great power and', 'Vin is a Mistborn of great power and skill', 'is a Mi', 'Mistborn of great power and skill.', 'Vin is a Mistborn of great power and', 'stborn of great power and skill', 'skill.']}]
# [{'id': '0', 'probability': [0.05736599194874784, 0.05406497241962602, 0.053004244496729705, 0.05250881889239606, 0.05219853223253319, 0.0516830207555171, 0.04995421362885291, 0.04908136691613107, 0.048904401319102266, 0.0487090172554923, 0.04851638018032756, 0.04790397874361128, 0.04781864996233897, 0.047307024327026034, 0.04534952998948529, 0.044763670332764925, 0.044433970255127686, 0.044219113430512595, 0.04418282205198882, 0.04375853387976895]}]

# %%
len(answers[0]['answer'])
# Out:
# 20

# %%
len(probabilities[0]['probability'])
# Out:
# 20

# %%
max_prob = 0;
correct_answer = " ";
for i in range(len(answers[0]['answer'])):
  if probabilities[0]['probability'][i] > max_prob:
    max_prob = probabilities[0]['probability'][i]
    correct_answer = answers[0]['answer'][i]

# %%
print(max_prob)
print(correct_answer)
# Out:
# 0.05736599194874784
# Mistborn of great power

# %% [markdown]
# #**Bert**

# %%
# !pip install transformers==3.1.0
import torch
from transformers import BertForQuestionAnswering
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
# Out:
# Requirement already satisfied: transformers==3.1.0 in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (0.0.46)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (21.3)
# Requirement already satisfied: tokenizers==0.8.1.rc2 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (0.8.1rc2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (2.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (1.19.5)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (0.1.96)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.1.0) (3.0.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.1.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.1.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.1.0) (1.1.0)

# %%
def answer_question_bert(question, answer_text):

    input_ids = tokenizer.encode(question, answer_text, max_length=512, truncation=True)

    print('Query has {:,} tokens.\n'.format(len(input_ids)))

    sep_index = input_ids.index(tokenizer.sep_token_id)

    num_seg_a = sep_index + 1

    num_seg_b = len(input_ids) - num_seg_a

    segment_ids = [0]*num_seg_a + [1]*num_seg_b

    assert len(segment_ids) == len(input_ids)

    start_scores, end_scores = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]))

    all_tokens = tokenizer.convert_ids_to_tokens(input_ids)

    #print(' '.join(all_tokens[torch.argmax(start_scores) : torch.argmax(end_scores)+1]))
    #print(f'score: {torch.max(start_scores)}')
    score = float(torch.max(start_scores))
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    answer = tokens[answer_start]

    for i in range(answer_start + 1, answer_end + 1):

        if tokens[i][0:2] == '##':
          answer += tokens[i][2:]
        else:
          answer += ' ' + tokens[i]
        #if tokens[i][0:2] == ' ':
         #   answer += tokens[i][2:]

        #else:
           # answer += ' ' + tokens[i]
    return answer, score, start_scores, end_scores, tokens
    #print('Answer: "' + answer + '"')

# %%
def expand_split_sentences(pdf_txt):
  import nltk
  nltk.download('punkt')
  new_chunks = nltk.sent_tokenize(pdf_txt)
  length = len(new_chunks)
  #for i in range(length):
    #tmp_token = tokenizer.encode(new_chunks[i])
    #print('The input has a total of {:} tokens.'.format(len(tmp_token)))

  new_df = [];
  for i in range(length):
    paragraph = ""
    for j in range(i, length):
      #tmp_str = paragraph + new_chunks[j]
      tmp_token = tokenizer.encode(paragraph + new_chunks[j])
      length_token = len(tmp_token)
      if length_token < 510:
        #print(length_token)
        paragraph = paragraph + new_chunks[j]
      else:
        #print(length_token)
        break;
    #print(len(tokenizer.encode(paragraph)))
    new_df.append(paragraph)
  return new_df
  #for i in new_df:
    #print(i)

# %%
def bert_drive(file_name, question):
  import numpy
  text = pdf_extract(file_name)
  max_score = 0;
  final_answer = ""
  new_df = expand_split_sentences(text)
  tokens = []
  s_scores = numpy.array([])
  e_scores = numpy.array([])
  for new_context in new_df:
    #new_paragrapgh = new_paragrapgh + answer_question(question, answer_text)
    ans, score, start_score, end_score, token = answer_question_bert(question, new_context)
    if score > max_score:
      max_score = score
      s_scores = start_score.detach().numpy().flatten()
      e_scores = end_score.detach().numpy().flatten()
      tokens = token
      final_answer = ans
  return final_answer, s_scores, e_scores, tokens

# %% [markdown]
# ##**Flask Server**

# %%
# !pip install Flask
# !pip install pyrebase
# !pip install flask-ngrok
# !pip install werkzeug
# Out:
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask) (2.0.1)
# Requirement already satisfied: pyrebase in /usr/local/lib/python3.7/dist-packages (3.0.27)
# Requirement already satisfied: requests==2.11.1 in /usr/local/lib/python3.7/dist-packages (from pyrebase) (2.11.1)
# Requirement already satisfied: oauth2client==3.0.0 in /usr/local/lib/python3.7/dist-packages (from pyrebase) (3.0.0)
# Requirement already satisfied: gcloud==0.17.0 in /usr/local/lib/python3.7/dist-packages (from pyrebase) (0.17.0)
# Requirement already satisfied: pycryptodome==3.4.3 in /usr/local/lib/python3.7/dist-packages (from pyrebase) (3.4.3)
# Requirement already satisfied: requests-toolbelt==0.7.0 in /usr/local/lib/python3.7/dist-packages (from pyrebase) (0.7.0)
# Requirement already satisfied: python-jwt==2.0.1 in /usr/local/lib/python3.7/dist-packages (from pyrebase) (2.0.1)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from gcloud==0.17.0->pyrebase) (0.17.4)
# Requirement already satisfied: protobuf!=3.0.0.b2.post1,>=3.0.0b2 in /usr/local/lib/python3.7/dist-packages (from gcloud==0.17.0->pyrebase) (3.17.3)
# Requirement already satisfied: googleapis-common-protos in /usr/local/lib/python3.7/dist-packages (from gcloud==0.17.0->pyrebase) (1.53.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gcloud==0.17.0->pyrebase) (1.15.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from oauth2client==3.0.0->pyrebase) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client==3.0.0->pyrebase) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from oauth2client==3.0.0->pyrebase) (0.2.8)
# Requirement already satisfied: jws>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from python-jwt==2.0.1->pyrebase) (0.1.3)
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.7/dist-packages (0.0.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.11.1)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
# !pip install crypto #install due to error occured in pyrebase
# !pip install pycrypto ##install due to error occured in pyrebase
# Out:
# Requirement already satisfied: crypto in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: Naked in /usr/local/lib/python3.7/dist-packages (from crypto) (0.1.31)
# Requirement already satisfied: shellescape in /usr/local/lib/python3.7/dist-packages (from crypto) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from Naked->crypto) (2.11.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Naked->crypto) (3.13)
# Collecting pycrypto
#   Using cached pycrypto-2.6.1.tar.gz (446 kB)
# Building wheels for collected packages: pycrypto
#   Building wheel for pycrypto (setup.py) ... done
#   Created wheel for pycrypto: filename=pycrypto-2.6.1-cp37-cp37m-linux_x86_64.whl size=499932 sha256=46062d1f9e9c96670a2e5a7d087c434d46801ff277e8443eb511aeb41d330b61
#   Stored in directory: /root/.cache/pip/wheels/cf/85/ba/bbd7c96add459de7598fb424e5ff2309baf2095c844ac0f191
# Successfully built pycrypto
# Installing collected packages: pycrypto
# Successfully installed pycrypto-2.6.1

# %%
import pyrebase
import os
import glob


config = {
  "apiKey": "AIzaSyC5FBYgV2gML7C1bqUEjiIbrkMCqlJ9Ba8",
  "authDomain": "docyqa-b6c3c.firebaseapp.com",
  "projectId": "docyqa-b6c3c",
  "databaseURL" : "",
  "storageBucket": "docyqa-b6c3c.appspot.com",
  "messagingSenderId": "152415243594",
  "appId": "1:152415243594:web:77f52516470de3642005b3",
  "measurementId": "G-9985TB71HF"
}

firebase = pyrebase.initialize_app(config)
storage = firebase.storage()

def clear_folder():
  files = glob.glob('docs/*')
  for f in files:
      os.remove(f)

def fetching_pdf(file_name):
  clear_folder()
  storage.child("docs").child(file_name).download("docs/" + file_name)

# %%
from flask import Flask
from flask import request
from flask_ngrok import run_with_ngrok

app = Flask(__name__)
run_with_ngrok(app)

@app.route('/', methods = ['POST'])
def question_answering_system():
  approach = request.form['approach']
  file_name = request.form['file_name']
  question = request.form['question']
  fetching_pdf(file_name)
  if(approach == "1"):
    answer = naive_drive(file_name, question)
    return answer
  elif(approach == "2"):
    answer = word2vec_drive(file_name, question)
    return answer
  elif(approach == "3"):
    answer = glove_drive(file_name, question)
    return answer
  elif(approach == "4"):
    answer, s_scores, e_scores, tokens = bert_drive(file_name, question)
    return answer
  else:
    return "null"

# %%
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://fc4f-35-230-161-168.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [25/Nov/2021 10:34:36] "POST / HTTP/1.1" 200 -
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Token indices sequence length is longer than the specified maximum sequence length for this model (522 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (574 > 512). Running this sequence through the model will result in indexing errors
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Token indices sequence length is longer than the specified maximum sequence length for this model (556 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (533 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (526 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (525 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (515 > 512). Running this sequence through the model will result in indexing errors
# Query has 504 tokens.
#
# Query has 495 tokens.
#
# Query has 477 tokens.
#
# Query has 454 tokens.
#
# Query has 512 tokens.
#
# Query has 512 tokens.
#
# Query has 512 tokens.
#
# Query has 502 tokens.
#
# Query has 464 tokens.
#
# Query has 437 tokens.
#
# Query has 393 tokens.
#
# Query has 342 tokens.
#
# Query has 323 tokens.
#
# Query has 276 tokens.
#
# Query has 249 tokens.
#
# Query has 228 tokens.
#
# Query has 198 tokens.
#
# Query has 166 tokens.
#
# Query has 73 tokens.
#
# Query has 50 tokens.
#
# Query has 29 tokens.
# 127.0.0.1 - - [25/Nov/2021 10:36:20] "POST / HTTP/1.1" 200 -
